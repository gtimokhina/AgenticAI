# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# Async LangGraph

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

# %% [markdown]
# Create a posh notification Tool

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

# %%
tool_push = Tool(
    name="send_push_notification",
    func=push,
    description="useful when you want to send a push notification"
)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# %%
async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/gulnaratimokhina/Library/Caches/ms-playwright/chromium-1169/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=136.0.7103.25>

# %%
tool_dict = {tool.name:tool for tool in tools}
navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")


   
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Underscored Style Travel Sports Science Climate
# Weather Ukraine-Russia War Israel-Hamas War Games More US World
# Politics Business Health Entertainment Underscored Style Travel Sports
# Science Climate Weather Ukraine-Russia War Israel-Hamas War Games
# Watch Listen Live TV Subscribe Sign in My Account Settings Newsletters
# Topics you follow Sign out Your CNN account Sign in to your CNN
# account Sign in My Account Settings Newsletters Topics you follow Sign
# out Your CNN account Sign in to your CNN account Live TV Listen Watch
# Edition US International Arabic Español Edition US International
# Arabic Español US Crime + Justice World Africa Americas Asia Australia
# China Europe India Middle East United Kingdom Politics Trump Facts
# First CNN Polls 2025 Elections Business Tech Media Calculators Videos
# Markets Pre-markets After-Hours Fear & Greed Investing Markets Now
# Nightcap Health Life, But Better Fitness Food Sleep Mindfulness
# Relationships CNN Underscored Electronics Fashion Beauty Health &
# Fitness Home Reviews Deals Gifts Travel Outdoors Pets Entertainment
# Movies Television Celebrity Tech Innovate Foreseeable Future Mission:
# Ahead Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# Videos Sports Pro Football College Football Basketball Baseball Soccer
# Olympics Hockey Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch Live
# TV CNN Headlines CNN Shorts Shows A-Z CNN10 CNN Max CNN TV Schedules
# FlashDocs Listen CNN 5 Things Chasing Life with Dr. Sanjay Gupta The
# Assignment with Audie Cornish One Thing Tug of War CNN Political
# Briefing The Axe Files All There Is with Anderson Cooper All CNN Audio
# podcasts Games Daily Crossword Jumble Crossword Photo Shuffle
# Sudoblock Sudoku 5 Things Quiz About CNN Subscribe Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Follow CNN info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Live Updates Fort Stewart shooting Trending
# Gerrymandering, explained Walking Dead actress death India tariffs
# Parasite detox Claire’s bankruptcy info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Kevin
# Lamarque/Reuters/File Trump says he intends to meet Putin and Zelensky
# as early as next week As the Trump administration’s sanctions deadline
# looms over Russia, the Kremlin said that US special envoy Steve
# Witkoff and Russian President Vladimir Putin held a “constructive and
# useful” meeting on Wednesday, according to Russian state media TASS.
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Jonathan Ernst/Reuters Vance dinner seen as potential
# way to clear air between Bondi, Patel on Epstein scandal A dinner
# scheduled Wednesday night at Vice President JD Vance’s residence was
# seen as an opportunity for Trump administration officials to realign
# amid the ongoing Jeffrey Epstein scandal, though it’s now in flux. •
# Analysis Analysis US District Court for the Southern District of New
# York Analysis An Epstein cover-up? Victims and allies suggest it’s
# happening now, under Trump For years, Republicans and MAGA influencers
# have been keen to rip the lid off a supposed government conspiracy to
# cover up information related to Jeffrey Epstein’s crimes and alleged
# associates. Many key figures who now serve in the Trump administration
# pledged to do exactly that. info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Suspect identified after 5
# soldiers were shot at Fort Stewart Show all • Live Updates Live
# Updates WJCL Live Updates The alleged gunman is a 28-year-old active-
# duty Army sergeant and is now in custody. Officials say fellow
# soldiers subdued the suspect. Five soldiers were shot in a shooting
# incident at the US Army’s Fort Stewart in Georgia, according to a
# verified Facebook page for Fort Stewart and the associated Hunter Army
# Airfield. Follow for live updates. • Video 2:42 WJCL Video Witness
# describes the scene 2:42 Five soldiers were shot at Fort Stewart in
# Georgia, according to officials. Witness Ron Peavey talks to CNN’s
# Boris Sanchez and describes what he saw. All wounded soldiers are in
# stable condition info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Play CNN Headlines - Source: CNN Watch the
# latest CNN Headlines info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. CDC Do you need to cleanse your body of
# parasites? A doctor explains Aug 6, 2025 Norma Galeana/CNN For
# Subscribers This farmer’s crops are dying. There’s no one to pick the
# fruit Aug 6, 2025 AJ_Watt/E+/Getty Images What you should know about
# metabolism, according to a nutrition scientist Aug 6, 2025 CNN,
# Reuters Video Director says his film about Hiroshima and Nagasaki is
# ‘a sacred duty’ 2:54 Aug 6, 2025 info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Pavlo Fedykovych For
# Subscribers Inside an abandoned secret nuclear missile base deep in
# the forests of Lithuania Jul 31, 2025 Herve Lenain/Alamy French resort
# town cracks down on ‘half-naked’ visitors Jul 28, 2025 Al
# Drago/Bloomberg/Getty Images For Subscribers From flag poles to a $200
# million ballroom: Inside Trump’s ‘legacy project’ at the White House
# Aug 2, 2025 Miami Herald/Getty Images Analysis In the Epstein scandal,
# like other Washington storms, the victims are an afterthought Aug 1,
# 2025 Prashanth Vishwanathan/Bloomberg/Getty Images Here’s what could
# get more expensive from Trump’s massive tariff hikes Aug 1, 2025
# Mindful Media/iStockphoto/Getty Images Strengthen your feet with a
# simple daily routine from a podiatrist Aug 5, 2025 CNN / Deltec Video
# How these round homes survive hurricanes 3:07 Jul 25, 2025 Simone
# Risoluti/Vatican Media/Reuters For Subscribers Faith, flags and deep-
# dish pizza: Pope Leo shows Gen Z appeal as a million young people turn
# out in Rome Aug 3, 2025 Carol Yepes/Moment RF/Getty Images Indoor air
# contains thousands of microplastics small enough to penetrate deep
# into our lungs, study finds Jul 30, 2025 Soccorso Alpino e
# Speleologico Veneto - CNSAS A British hiker needed rescuing from the
# Italian Dolomites. He’s now facing a $16,000 fine Aug 5, 2025 Doritos
# Doritos thinks this flavor is its next ‘Cool Ranch’ Aug 2, 2025 TikTok
# / @seht876 / @geiamendozaaa / @seht876 Video This Swiss River is so
# clean, locals use it to commute to work 2:36 Jul 24, 2025 Noriko
# Hayashi for CNN For Subscribers CEO who spent $10M on original Birkin
# bag says ‘I felt sick to my stomach’ Aug 1, 2025 Cliff
# Berger/Southwest Area Incident Management Team 2, via TMX Video This
# is how a fire cloud formed in the Grand Canyon ‘megafire’ 1:02 Aug 2,
# 2025 Mike Fuentes/Bloomberg/Getty Images He tried building smartphones
# in the US over a decade ago. He has advice for companies trying it
# today Aug 4, 2025 Darn Tough Forget cotton — Darn Tough merino wool
# socks are your feet’s new BFF Aug 5, 2025 CNN Video College grads
# compete with AI for entry-level jobs 2:11 Aug 4, 2025 Henry T.
# Casey/CNN Underscored We found the best over-ear headphones after
# years of testing Aug 2, 2025 CNN Video Dr. Sanjay Gupta exposes
# deepfake ads promoting fake health cures with his likeness 1:44 Jul
# 31, 2025 Janna Tew/Salter House People are wearing nightgowns anywhere
# but to bed Jul 29, 2025 Photo Illustration by Jason
# Lancaster/CNN/Getty Images ‘Ozempic face’ may be driving a cosmetic
# surgery boom Jul 30, 2025 Michael Peterson/GTRI ‘Megaflash’ lightning
# bolt traveled over 500 miles, setting a new record, study says Jul 31,
# 2025 Jose Perez/Bauer-Griffin/GC Images/Getty Images What has America
# learned from the Sydney Sweeney situation? We asked the experts Aug 4,
# 2025 Carlo Zanella Fed-up Italian farmers set up mountain turnstiles
# to charge access to Instagram hot spots Jul 31, 2025 Seraphinne
# Vallora Your favorite model? Thanks to AI, they might not be real Jul
# 31, 2025 PATRICK T. FALLON/AFP/AFP via Getty Images Video Short
# flights, big pollution: the private jet problem 2:42 Jul 31, 2025
# naikon/iStockphoto/Getty Images What you eat may impact your lung
# cancer risk, according to a new study Jul 29, 2025 Hans
# Lucas/AFP/Getty Images Analysis A viable Palestinian state remains far
# off, despite growing international clamor Aug 2, 2025
# fermate/iStockphoto/Getty Images Mosquitoes bite! 5 tips for making
# yourself less attractive to them Jul 30, 2025 CNN Video How cargo
# ships deliver made-in-China goods to your door 10:26 Jul 29, 2025
# Barry Neild/CNN The world’s first passenger jet was a luxurious death
# trap. Now it’s been brought back to life Jul 29, 2025 Gabe Ramirez,
# CNN Video In a city prone to natural disasters, this museum uses
# thoughtful design and hidden tech to keep staff and artworks safe 3:17
# Aug 1, 2025 Kayla Bartkowski/Getty Images For Subscribers Trump
# administration takes all-of-government approach to target transgender
# community Jul 21, 2025 FG Trade/E+/Getty Images Worried about
# Alzheimer’s? Start walking, according to a new 10-year study Jul 28,
# 2025 Photo illustration by Ian Berry/CNN/Adobe Stock Extreme heat is
# miserable and dangerous. It’s also making us age faster Jul 25, 2025
# CNN Video The town wanted his farm for affordable housing. Then came
# the MAGA storm 3:53 Jul 25, 2025 CNN First on CNN Fighting early-stage
# Alzheimer’s with intensive lifestyles changes works, study finds Jul
# 29, 2025 Tom Winger/500px/Getty Images This upstate New York town is a
# showstopper for scenery Jun 26, 2025 Kyle Grillot/Reuters For
# Subscribers Where the next deadly flood wave could strike Jul 24, 2025
# Jonathan Cohen/Alamy Stock Photo We searched for America’s best towns
# to visit. Here are the top 10 Jun 27, 2025 CNN Video ‘It’s a type of
# torture’: Hear what it’s like inside ‘Alligator Alcatraz’ 4:54 Jul 25,
# 2025 cnn Video Meat consumption levels are unsustainable. Going vegan
# isn’t the only answer 2:59 Jul 15, 2025 Kent Nishimura/Getty Images
# For Subscribers The FBI prepares to leave its ‘monstrosity’ of a home
# – but may end up back where it started Jul 19, 2025 Molly Flores/CNN
# Underscored CNN Underscored The 35 best fanny packs and belt bags,
# according to stylists and editors Jul 24, 2025 Ian Berry, CNN Cycling
# like a pro… for a day: How amateurs measure themselves up to pros on
# one of the world’s toughest stages Jul 25, 2025 Will Lanzoni/CNN
# ‘These mountains are still here.’ Asheville is ready for your visit
# Jun 26, 2025 Sonoma County Tourism Once ‘the world’s egg basket,’ this
# Gold Rush-era boomtown still delivers culinary riches Jun 26, 2025
# Molly Flores/CNN Underscored CNN Underscored The 25 best sympathy gift
# ideas to offer solace and support, according to etiquette experts Jul
# 23, 2025 Rebeca Wright/CNN ‘It’s all still here.’ This seafaring town
# brings the past to life Jun 26, 2025 CNN Video CNN reporter attempts
# airshow maneuvers in the Goodyear blimp 2:17 Jul 27, 2025 info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# More Top Stories • For Subscribers For Subscribers Courtesy McKenzie
# Lange For Subscribers Conversion therapy is quietly spreading across
# America again. These survivors say it nearly cost them their lives
# Video 911 calls and bodycam footage shed light on Manhattan gunman’s
# troubled past 1:32 Capital Jewish Museum shooting suspect indicted on
# murder, hate crime charges, could face death penalty Video Nicaraguan
# migrant narrowly outruns ICE, barricades himself at home 2:19 Where
# tariff money goes, myths about metabolism, ancient ‘ice mummy’: Catch
# up on the day’s stories B/R The Yankees are in full meltdown mode RFK
# terminates funding for mRNA vaccines info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Gender INequality
# CNN Police say bystanders were told not to save a drowning woman.
# Killings didn’t stop there “Social control” campaigns aimed at
# minority groups have a long history in Colombia, with local vigilantes
# dealing death and displacement in the name of law and order. • Video
# 9:09 CNN Video A trans woman with broken limbs was thrown into a river
# to drown. Sara Millerey’s killing was brutal, but not unique 9:09
# Colombia’s gang members tell CNN of a killing campaign aimed at LGBTQ
# people. Trans women, like Sara Millerey and Nawar Jimenez, are paying
# the price. info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Redistricting Fight CNN How Texas Republicans want to
# dismantle Democratic districts Texas Republicans have proposed a new
# congressional map for the state, with the goal of flipping five
# Democratic seats in next year’s midterm elections. • Opinion 1:56 CNN
# Opinion Everyone should support those Texas lawmakers, Van Jones says
# 1:56 CNN Senior Political Commentator Van Jones commemorates the 60th
# anniversary of the signing of the Voting Rights Act by recalling how
# civil rights activists fought for the bill, and how the Texas state
# Democratic lawmakers’ current bid to prevent Republicans’
# gerrymandering efforts honors democracy and a “meaningful right to
# vote.” Ad Feedback info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Ad Feedback CNN Underscored Molly
# Flores/CNN Underscored Shackets are the greatest mash-up since jorts.
# Here are stylists’ 17 favorites Aug 6, 2025 Bonne Maman The beloved
# Bonne Maman Advent Calendar has arrived. Grab it before it’s gone Aug
# 5, 2025 Amina Lake Abdelrahman/CNN Underscored Tons of Dyson products
# are seriously marked down with this rare sale Aug 4, 2025 Ad Feedback
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Tariffs Dhiraj Singh/Bloomberg/Getty Images Trump
# threatens India with 50% tariffs for importing Russian oil • Video
# 1:48 CNN Video Expert weighs in on Trump’s tariff threat 1:48 •
# Analysis Analysis AP Analysis Trump’s tariff strategy crashes into
# geopolitical reality info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Trump Administration • Video 4:21 CNN Video
# Voters in battleground Arizona seeing impacts of Trump’s megabill 4:21
# Jim Watson/AFP/Getty Images/File DOJ tells judge it will ask Supreme
# Court to quickly rule on constitutionality of Trump’s birthright
# citizenship order CNN He’s opening a steakhouse in one of the top
# battlegrounds. Hear what he thinks about Trump’s megabill info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences. For
# Subscribers • For Subscribers For Subscribers Wojtek
# Radwanski/AFP/Getty Images For Subscribers ‘Everyone is terrified of
# him’: Corey Lewandowski’s power at Homeland Security is growing • For
# Subscribers For Subscribers David Dee Delgado/Reuters For Subscribers
# See where ICE is making the majority of arrests, by state • For
# Subscribers For Subscribers Greg Kahn/The New York Times/Redux For
# Subscribers Laura Loomer has the White House scrambling again — and
# she’s far from finished Ad Feedback Ad Feedback CNN Underscored info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. Best-in-class The sharpening process using the Presto
# 08810 Professional was intuitive and simple. Suzanne Kattau/CNN
# Underscored Bring your knives back to life with this top-tested
# kitchen knife sharpener 11 of the best over-the-toilet organizers for
# every type of bathroom Amazon’s back-to-school sale has deep deals  on
# backpacks, MacBooks, pens and more A good flashlight is a must when
# the power goes out. These 3 are actually worth your cash I’m eyeing
# these 32 best back-to-school shoe sales from Hoka, Crocs, Adidas and
# more info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Expert-backed guides Kai Burkhardt/CNN Underscored A
# bidet can seriously improve your life. Here are the 3 best The Home
# Depot’s new Halloween collection just dropped, and it’s scarier than
# ever Belt bags and fanny packs don’t have to be tacky. Here are 35
# stylist-approved ones Drench your patio in pretty colors and prints
# with these expert-recommended outdoor rugs Over 35 pieces from
# Athleta, Lands’ End and more are up to 78% off for back-to-school info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. Editors' picks Apple Everything worth buying during
# Apple’s back-to-school sale 17 game-changing car products our editors
# never drive without, starting at $5 The best under-eye patches and
# masks to depuff and hydrate, tried and tested Laptops, lunch boxes and
# more are up to 80% off during the Staples back-to-school sale Delta
# Platinum or Delta Reserve? Here’s the better card, according to a top
# Delta frequent flyer info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. CNN Sports Jeff Roberson/AP Jen Pawol will
# be MLB’s first woman to umpire in a regular-season game Courtesy the
# Maclean brothers Three brothers, one boat and a 9,000-mile mission
# Kirby Lee/Imagn/ Reuters Another sex toy thrown onto WNBA court, this
# time appears to hit Indiana Fever guard Sophie Cunningham info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Bleacher Report Show all Video: Shohei Ohtani hits homerun for 1,000th
# hit NASCAR star: ‘Talladega Nights’ bad for sport 21-year-old Red Sox
# rookie signs megadeal NFL head coach bloodied after breaking up fight
# CBB coach says this basketball position is dead Ad Feedback America’s
# Best Towns info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Rebecca Wright/CNN This maritime town offers boating,
# great seafood and more than 250 years of history info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. • Video
# 2:36 Gabe Ramirez Video See why George Lucas chose this small town for
# his iconic film’s setting 2:36 Will Lanzoni/CNN This ‘magical’ North
# Carolina mountain town is our No. 3 best town to visit • Video 2:32
# CNN Video ‘It’s hard to go to work’: This Oregon town is too much fun
# 2:32 Halbergman/iStockphoto/Getty Images Jaw-dropping scenery makes
# this our No. 7 best town to visit this year • Video 2:36 CNN Video
# This Montana town has amazing food, fly fishing, and even surfing in
# the center of downtown 2:36 Garrett Lockrem/Mt. Bachelor People
# flocked to this town during the pandemic and never left. It’s our No.
# 4 best town to visit info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. World Veronika Silchenko American
# journalist found after going missing on hike in Norwegian national
# park Marvin Recinos/AFP/Getty Images US sides with El Salvador on
# eliminating presidential term limits, prompting democracy debate •
# Video 1:47 CNN Video Women in Gaza ‘embarrassed’ by dire personal
# hygiene situation 1:47 info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Climate and environment Flash flooding
# struck northern India on Tuesday prompting at least 70 people to be
# evacuated while dozens remain missing, according to officials in
# Uttarakhand. At least four people have died in the flooding, which
# triggered a mudslide that was caught on video as it engulfed a
# Himalayan village. Newsflare Wall of water slams Himalayan village,
# leaving multiple dead and dozens feared trapped or missing Idriss
# Bigou-Gilles/AFP/Getty Images French firefighters battle to contain
# blaze that killed elderly woman and tore through area bigger than
# Paris Rebecca Wright/CNN Australia’s Great Barrier Reef devastated by
# worst coral bleaching on record, new report finds info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Health and Wellness ridvan_celik/E+/Getty Images Childhood verbal
# abuse may have deep mental health impacts, study finds BSIP/Universal
# Images Group/Getty Images Nearly two dozen people in Florida are ill
# after drinking raw milk from the same farm • Video 3:51 CNN/Getty
# Images Video RFK Jr. slashed mRNA vaccine development funding. A Nobel
# Prize winner just responded 3:51 info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Business and Economy Craig
# T Fruchtman/Getty Images Apple will invest $100 billion to make US
# iPhone parts as Trump says a big chip tariff is coming Joshua
# Roberts/Reuters/File Trump is meeting with advisers about his next Fed
# pick. It may be a temporary assignment Brendan Smialowski/AFP/Getty
# Images Trump says the Bureau of Labor Statistics orchestrated a
# ‘scam.’ Here’s how the jobs report really works info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. Science
# and discovery Juan Mabromata/AFP/Getty Images Acting NASA chief fast-
# tracks plans to put a nuclear reactor on the moon Brett
# Groehler/University Minnesota Duluth A black goo was oozing from a
# ship on the Great Lakes — and teeming with life Researchers in
# Australia have found a new supersized species of stick insect.
# Professor Angus Emmott, James Cook University Meet the new species of
# giant stick insect that weighs about the same as a golf ball info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Entertainment and Culture Jace Downs/AMC ‘The Walking Dead’ actress
# Kelley Mack dies at 33 Jeff Kravitz/FilmMagic/Getty Images Hulk
# Hogan’s daughter explains her personal reason for not attending her
# father’s funeral • CNN Exclusive CNN Exclusive Jeenah
# Moon/Reuters/File CNN Exclusive Attorney for Combs says they’ve
# approached Trump administration about pardon info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. Life, But
# Greener Show all • Video 2:42 PATRICK T. FALLON/AFP/AFP via Getty
# Images Video The numbers behind the private jet backlash 2:42 • Video
# 2:36 TikTok / @seht876 / @geiamendozaaa / @seht876 Video This Swiss
# river is so clean, locals use it to commute to work 2:36 • Video 1:48
# CNN Video Why Billie Eilish insists on special rules at all her
# concerts 1:48 info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Latest Politics Tom Williams/CQ-Roll
# Call/Getty Images GOP Rep. Cory Mills accused by ex-girlfriend of
# threatening to release sexually explicit images, videos of her Patrick
# Semansky/AP/File Former senior Biden aide appears before House
# committee in probe of former president’s alleged mental decline Justin
# Sullivan/Getty Images/File Stanford’s student newspaper sues Trump
# administration over use of immigration law to target pro-Palestinian
# students info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Travel and tourism Yara Nardi/Reuters Italy gives
# final go-ahead for landmark Sicily bridge project Kevin
# Lamarque/Reuters US demands up to $15,000 visa bond for tourists and
# business travelers from Zambia and Malawi • Video 3:17 CNN Video How
# Getty Museum kept its priceless art safe during the Palisades Fire
# 3:17 Paid Content More from CNN Style info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. • Video 2:00
# Noriko Hayashi for CNN • Video 2:00 Video Winning bidder of $10M
# Birkin bag wanted to inflict ‘psychological damage’ on opponents 2:00
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Courtesy Cecilie Bahnsen ‘Something you can move in’:
# How this designer became the go-to for unconventional brides Ad
# Feedback info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. CNN Games + Quizzes Show all • Today's crossword
# Today's crossword CNN Today's crossword No pencil or eraser required •
# Sudoblock Sudoblock CNN Sudoblock Sudoku + Blocks = addictive tile-
# matching puzzle • Jumble Crossword Jumble Crossword CNN Jumble
# Crossword Test your smarts with this scrambled word game • Weekly news
# quiz Weekly news quiz cnn Weekly news quiz What do you remember from
# the week that was? Paid Partner Content In case you missed it info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Nebraska Public Media Tensions erupt at Nebraska GOP congressman’s
# town hall info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Ukrainian tennis player Elina Svitolina faces hateful
# abuse after loss, blames ‘shameful’ bettors China used to fine couples
# for having too many babies. Now it can’t pay them enough Weather
# Service is now hiring back hundreds of positions that got cut in the
# DOGE chaos 4 killed in medical transport plane crash on Navajo Nation,
# tribal authorities say Trump says he wants strong testing to keep
# transgender athletes out of women’s sports at 2028 Olympics Rwanda
# agrees to take in up to 250 migrants deported from the US Tennis coach
# Patrick Mouratoglou opens up on recent split with Naomi Osaka
# Subscribe Sign in My Account Settings Newsletters Topics you follow
# Sign out Your CNN account Sign in to your CNN account Live TV Listen
# Watch US Crime + Justice World Africa Americas Asia Australia China
# Europe India Middle East United Kingdom Politics Trump Facts First CNN
# Polls 2025 Elections Business Tech Media Calculators Videos Markets
# Pre-markets After-Hours Fear & Greed Investing Markets Now Nightcap
# Health Life, But Better Fitness Food Sleep Mindfulness Relationships
# CNN Underscored Electronics Fashion Beauty Health & Fitness Home
# Reviews Deals Gifts Travel Outdoors Pets Entertainment Movies
# Television Celebrity Tech Innovate Foreseeable Future Mission: Ahead
# Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Pro Football College Football Basketball Baseball
# Soccer Olympics Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Ukraine-Russia War Israel-Hamas War
# Watch Live TV CNN Headlines CNN Shorts Shows A-Z CNN10 CNN Max CNN TV
# Schedules FlashDocs Listen CNN 5 Things Chasing Life with Dr. Sanjay
# Gupta The Assignment with Audie Cornish One Thing Tug of War CNN
# Political Briefing The Axe Files All There Is with Anderson Cooper All
# CNN Audio podcasts Games Daily Crossword Jumble Crossword Photo
# Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Subscribe Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Watch Listen Live TV Follow CNN Subscribe Sign in My Account
# Settings Newsletters Topics you follow Sign out Your CNN account Sign
# in to your CNN account Terms of Use Privacy Policy Do Not Sell Or
# Share My Personal Information Ad Choices Accessibility & CC About
# Subscribe Newsletters Transcripts Help Center © 2025 Cable News
# Network. A Warner Bros. Discovery Company. All Rights Reserved. CNN
# Sans ™ & © 2016 Cable News Network. Global Privacy Control (GPC)
# signal detected.  Your personal information will not be sold or
# shared. Do Not Sell or Share My Personal Data For residents of certain
# states only.  Please visit our U.S. State Supplement for more
# information. Privacy Policy Manage Consent Preferences Allow the Sale,
# Sharing or use of My Personal information for Targeted Advertising
# Allow the Sale, Sharing or use of My Personal information for Targeted
# Advertising If you switch this toggle to “no,” we will not sell or
# share your personal information with third parties for advertising
# targeted to this device. Please see our Privacy Center for additional
# preferences. Strictly Necessary Cookies Always Active These cookies
# are necessary for the website to function and cannot be switched off
# in our systems. You can set your browser to block or alert you about
# these cookies, but some parts of the site will not work. Back Button
# Cookie List Search Icon Filter Icon Clear checkbox label label Apply
# Cancel Consent Leg.Interest checkbox label label checkbox label label
# checkbox label label Confirm My Choices Legal Terms and Privacy By
# clicking "Agree", you have read and agree to the Terms of Use and
# agree to the collection and use of your information by cookies and
# similar technologies, as set forth in our Privacy Policy . Agree

# %% [markdown]
# Combine all tools

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)

def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 1. Structured Outputs
# 2. A multi-agent flow

# %%
from typing import Annotated, TypedDict, List, Dict, Any, Optional
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import ToolNode
from langgraph.graph.message import add_messages
from pydantic import BaseModel, Field
from IPython.display import Image, display
import gradio as gr
import uuid
from dotenv import load_dotenv

# %%
# First define a structured output

class EvaluatorOutput(BaseModel):
    feedback: str = Field(description="Feedback on the assistant's response")
    success_criteria_met: bool = Field(description="Whether the success criteria have been met")
    user_input_needed: bool = Field(description="True if more input is needed from the user, or clarifications, or the assistant is stuck")

# %%
# the state now is more complex

class State(TypedDict):
    messages: Annotated[List[Any], add_messages]
    success_criteria: str
    feedback_on_work: Optional[str]
    success_criteria_met: bool
    user_input_needed: bool

# %%
# Get our async Playwright tools
import nest_asyncio
nest_asyncio.apply()
async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
# Initialize the LLMs

worker_llm = ChatOpenAI(model="gpt-4o-mini")
worker_llm_with_tools = worker_llm.bind_tools(tools)

evaluator_llm = ChatOpenAI(model="gpt-4o-mini")
evaluator_llm_with_output = evaluator_llm.with_structured_output(EvaluatorOutput)

# %%
# The worker node and system prompt

def worker(state: State) -> Dict[str, Any]:
    system_message = f"""You are a helpful assistant that can use tools to complete tasks.
You keep working on a task until either you have a question or clarification for the user, or the success criteria is met.
This is the success criteria:
{state['success_criteria']}
You should reply either with a question for the user about this assignment, or with your final response.
If you have a question for the user, you need to reply by clearly stating your question. An example might be:

Question: please clarify whether you want a summary or a detailed answer

If you've finished, reply with the final answer, and don't ask a question; simply reply with the answer.
"""
    
    if state.get("feedback_on_work"):
        system_message += f"""
Previously you thought you completed the assignment, but your reply was rejected because the success criteria was not met.
Here is the feedback on why this was rejected:
{state['feedback_on_work']}
With this feedback, please continue the assignment, ensuring that you meet the success criteria or have a question for the user."""
    
    # Add in the system message

    found_system_message = False
    messages = state["messages"]
    for message in messages:
        if isinstance(message, SystemMessage):
            message.content = system_message
            found_system_message = True
    
    if not found_system_message:
        messages = [SystemMessage(content=system_message)] + messages
    
    # Invoke the LLM with tools
    response = worker_llm_with_tools.invoke(messages)
    
    # Return updated state
    return {
        "messages": [response],
    }

# %%
def worker_router(state: State) -> str:
    last_message = state["messages"][-1]
    
    if hasattr(last_message, "tool_calls") and last_message.tool_calls:
        return "tools"
    else:
        return "evaluator"

# %%
def format_conversation(messages: List[Any]) -> str:
    conversation = "Conversation history:\n\n"
    for message in messages:
        if isinstance(message, HumanMessage):
            conversation += f"User: {message.content}\n"
        elif isinstance(message, AIMessage):
            text = message.content or "[Tools use]"
            conversation += f"Assistant: {text}\n"
    return conversation

# %%
def evaluator(state: State) -> State:
    last_response = state["messages"][-1].content

    system_message = """You are an evaluator that determines if a task has been completed successfully by an Assistant.
Assess the Assistant's last response based on the given criteria. Respond with your feedback, and with your decision on whether the success criteria has been met,
and whether more input is needed from the user."""
    
    user_message = f"""You are evaluating a conversation between the User and Assistant. You decide what action to take based on the last response from the Assistant.

The entire conversation with the assistant, with the user's original request and all replies, is:
{format_conversation(state['messages'])}

The success criteria for this assignment is:
{state['success_criteria']}

And the final response from the Assistant that you are evaluating is:
{last_response}

Respond with your feedback, and decide if the success criteria is met by this response.
Also, decide if more user input is required, either because the assistant has a question, needs clarification, or seems to be stuck and unable to answer without help.
"""
    if state["feedback_on_work"]:
        user_message += f"Also, note that in a prior attempt from the Assistant, you provided this feedback: {state['feedback_on_work']}\n"
        user_message += "If you're seeing the Assistant repeating the same mistakes, then consider responding that user input is required."
    
    evaluator_messages = [SystemMessage(content=system_message), HumanMessage(content=user_message)]

    eval_result = evaluator_llm_with_output.invoke(evaluator_messages)
    new_state = {
        "messages": [{"role": "assistant", "content": f"Evaluator Feedback on this answer: {eval_result.feedback}"}],
        "feedback_on_work": eval_result.feedback,
        "success_criteria_met": eval_result.success_criteria_met,
        "user_input_needed": eval_result.user_input_needed
    }
    return new_state

# %%
def route_based_on_evaluation(state: State) -> str:
    if state["success_criteria_met"] or state["user_input_needed"]:
        return "END"
    else:
        return "worker"

# %%
# Set up Graph Builder with State
graph_builder = StateGraph(State)

# Add nodes
graph_builder.add_node("worker", worker)
graph_builder.add_node("tools", ToolNode(tools=tools))
graph_builder.add_node("evaluator", evaluator)

# Add edges
graph_builder.add_conditional_edges("worker", worker_router, {"tools": "tools", "evaluator": "evaluator"})
graph_builder.add_edge("tools", "worker")
graph_builder.add_conditional_edges("evaluator", route_based_on_evaluation, {"worker": "worker", "END": END})
graph_builder.add_edge(START, "worker")

# Compile the graph
memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
def make_thread_id() -> str:
    return str(uuid.uuid4())


async def process_message(message, success_criteria, history, thread):

    config = {"configurable": {"thread_id": thread}}

    state = {
        "messages": message,
        "success_criteria": success_criteria,
        "feedback_on_work": None,
        "success_criteria_met": False,
        "user_input_needed": False
    }
    result = await graph.ainvoke(state, config=config)
    user = {"role": "user", "content": message}
    reply = {"role": "assistant", "content": result["messages"][-2].content}
    feedback = {"role": "assistant", "content": result["messages"][-1].content}
    return history + [user, reply, feedback]

async def reset():
    return "", "", None, make_thread_id()

# %% [markdown]
# Launch Sidekick UI

# %%
with gr.Blocks(theme=gr.themes.Default(primary_hue="emerald")) as demo:
    gr.Markdown("## Sidekick Personal Co-worker")
    thread = gr.State(make_thread_id())
    
    with gr.Row():
        chatbot = gr.Chatbot(label="Sidekick", height=300, type="messages")
    with gr.Group():
        with gr.Row():
            message = gr.Textbox(show_label=False, placeholder="Your request to your sidekick")
        with gr.Row():
            success_criteria = gr.Textbox(show_label=False, placeholder="What are your success critiera?")
    with gr.Row():
        reset_button = gr.Button("Reset", variant="stop")
        go_button = gr.Button("Go!", variant="primary")
    message.submit(process_message, [message, success_criteria, chatbot, thread], [chatbot])
    success_criteria.submit(process_message, [message, success_criteria, chatbot, thread], [chatbot])
    go_button.click(process_message, [message, success_criteria, chatbot, thread], [chatbot])
    reset_button.click(reset, [], [message, success_criteria, chatbot, thread])

    
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1729, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/utils.py", line 861, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/ms/tbmtmjnd3sl_vn0ds8h3scnm0000gn/T/ipykernel_25039/2386308238.py", line 16, in process_message
#     result = await graph.ainvoke(state, config=config)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py", line 2788, in ainvoke
#     async for chunk in self.astream(
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py", line 2677, in astream
#     raise GraphRecursionError(msg)
# langgraph.errors.GraphRecursionError: Recursion limit of 25 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT
# Traceback (most recent call last):
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1729, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/gradio/utils.py", line 861, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/ms/tbmtmjnd3sl_vn0ds8h3scnm0000gn/T/ipykernel_25039/2386308238.py", line 16, in process_message
#     result = await graph.ainvoke(state, config=config)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py", line 2788, in ainvoke
#     async for chunk in self.astream(
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py", line 2655, in astream
#     async for _ in runner.atick(
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/futures.py", line 289, in __await__
#     yield self  # This tells Task to wait for completion.
#     ^^^^^^^^^^
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
#     future.result()
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/futures.py", line 202, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/tasks.py", line 316, in __step_run_and_handle_result
#     result = coro.throw(exc)
#              ^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py", line 440, in ainvoke
#     ret = await self.afunc(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 616, in run_in_executor
#     return await asyncio.get_running_loop().run_in_executor(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/futures.py", line 289, in __await__
#     yield self  # This tells Task to wait for completion.
#     ^^^^^^^^^^
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
#     future.result()
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/asyncio/futures.py", line 202, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/Users/gulnaratimokhina/.local/share/uv/python/cpython-3.12.11-macos-x86_64-none/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 607, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/ms/tbmtmjnd3sl_vn0ds8h3scnm0000gn/T/ipykernel_25039/2445825.py", line 36, in worker
#     response = worker_llm_with_tools.invoke(messages)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 5431, in invoke
#     return self.bound.invoke(
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 372, in invoke
#     self.generate_prompt(
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 957, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 776, in generate
#     self._generate_with_cache(
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 1022, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py", line 995, in _generate
#     response = self.client.create(**payload)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py", line 287, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py", line 925, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1242, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gulnaratimokhina/Documents/AgenticAIWorkspace/agenticAI/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1037, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_WQkcoYhJit4kybivJKwNwjOO", 'type': 'invalid_request_error', 'param': 'messages.[27].role', 'code': None}}
# During task with name 'worker' and id '67f46606-0969-1429-0a2e-7036ed09a5a7'

# %%
# Set up Graph Builder with State
graph_builder = StateGraph(State)

# Add nodes
graph_builder.add_node("worker", worker)
graph_builder.add_node("tools", ToolNode(tools=tools))
graph_builder.add_node("evaluator", evaluator)

# Add edges
graph_builder.add_conditional_edges("worker", worker_router, {"tools": "tools", "evaluator": "evaluator"})
graph_builder.add_edge("tools", "worker")
graph_builder.add_conditional_edges("evaluator", route_based_on_evaluation, {"worker": "worker", "END": END})
graph_builder.add_edge(START, "worker")

# Compile the graph
memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
